# %% [markdown]
# ## GPU Testing

# %%
import torch
t_cpu = torch.rand(500,500,500)
# %timeit t_cpu @ t_cpu
# Out:
# 1.44 s ± 38.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
t_gpu = torch.rand(500,500,500).cuda()
# %timeit t_gpu @ t_gpu
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-33782749742e> in <module>
# ----> 1 t_gpu = torch.rand(500,500,500).cuda()
#       2 get_ipython().run_line_magic('timeit', 't_gpu @ t_gpu')
#
# ~/anaconda3/lib/python3.6/site-packages/torch/cuda/__init__.py in _lazy_init()
#     159         raise RuntimeError(
#     160             "Cannot re-initialize CUDA in forked subprocess. " + msg)
# --> 161     _check_driver()
#     162     torch._C._cuda_init()
#     163     _cudart = _load_cudart()
#
# ~/anaconda3/lib/python3.6/site-packages/torch/cuda/__init__.py in _check_driver()
#      73 def _check_driver():
#      74     if not hasattr(torch._C, '_cuda_isDriverSufficient'):
# ---> 75         raise AssertionError("Torch not compiled with CUDA enabled")
#      76     if not torch._C._cuda_isDriverSufficient():
# ...
