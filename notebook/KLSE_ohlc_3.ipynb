# %% [markdown]
# # Get historical prices - OHLC

# %% [markdown]
# ## Common imports and functions

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import pandas as pd
import datetime as dt
import calendar as cal
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

from IPython.display import display
pd.options.display.max_columns = 50

# %% [markdown]
# ## Read the categorized stocks

# %%
df_stocks = pd.read_csv('../dataset/KLSE_category_2.csv')
df_stocks.info()
df_stocks.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 4 columns):
# code          108 non-null object
# name          108 non-null object
# yield_sum     108 non-null float64
# yield_mean    108 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 3.5+ KB
#    code                              name  yield_sum  yield_mean
# 0  5191      Tambun Indah Land Bhd (TAMB)      49.69     16.5633
# 1  5272       Ranhill Holdings Ltd (RANH)      48.11     24.0550
# 2  5161      JCY International Bhd (JCYI)      47.34     23.6700
# 3  5254   Boustead Plantations Bhd (BOPL)      47.29     23.6450
# 4  6084       Star Media Group Bhd (STAR)      45.65     15.2167
# 5  5078       Marine & General Bhd (MARI)      45.45     45.4500
# 6  8524  Taliworks Corporation Bhd (TWRK)      42.03     21.0150
# 7  4502            Media Prima Bhd (MPRM)      41.03     20.5150
# 8  5010    Tong Herr Resources Bhd (THRB)      40.67     13.5567
# 9  3859                 Magnum Bhd (MAGM)      39.69     19.8450

# %% [markdown]
# ## Get the URLs

# %%
df_lookup = pd.read_csv('../dataset/KLSE_lookup_investing.csv')
df_merged = pd.merge(df_stocks, df_lookup, how='left', left_on=['code'], right_on=['code'])
df_merged.rename(index=str, columns={'name_x': 'name'}, inplace=True)
df_merged.drop(['name_y'], axis=1,inplace=True)
df_merged['url'] = df_merged['url'].str[:-10]   ## Remove -dividends from the URL
# df_merged[~df_merged['name_y'].isnull()]
df_merged['url'].unique()
df_merged.to_csv('../dataset/KLSE_selected.csv'.format(c), encoding='utf-8', index=False, float_format='%g')
display(df_merged)
# Out:
#      code                                               name  yield_sum  \
# 0    5191                       Tambun Indah Land Bhd (TAMB)      49.69
# 1    5272                        Ranhill Holdings Ltd (RANH)      48.11
# 2    5161                       JCY International Bhd (JCYI)      47.34
# 3    5254                    Boustead Plantations Bhd (BOPL)      47.29
# 4    6084                        Star Media Group Bhd (STAR)      45.65
# 5    5078                        Marine & General Bhd (MARI)      45.45
# 6    8524                   Taliworks Corporation Bhd (TWRK)      42.03
# 7    4502                             Media Prima Bhd (MPRM)      41.03
# 8    5010                     Tong Herr Resources Bhd (THRB)      40.67
# 9    3859                                  Magnum Bhd (MAGM)      39.69
# 10   7157                         CYL Corporation Bhd (CYLC)      39.21
# 11   6009                          Pacific Orient Bhd (PACO)      38.43
# 12   1562                     Berjaya Sports Toto Bhd (BSTB)      37.92
# 13   5095                              HeveaBoard Bhd (HEVE)      37.69
# 14   5180              CapitaLand Malaysia Mall Trust (CAMA)      36.07
# 15   5109                        YTL Hospitality REIT (YTLR)      36.05
# 16   1198                               MAA Group Bhd (MAAS)      35.97
# 17   5436  Perusahaan Sadur Timah Malaysia Perstima Bhd (...      34.68
# 18   7237                              Power Root Bhd (POWE)      34.63
# 19   5236                Matrix Concepts Holdings Bhd (MATR)      33.15
# 20   5176         Sunway Real Estate Investment Trust (SUNW)      33.08
# 21   7099                       Atta Global Group Bhd (ATTA)      32.50
# 22   5123                        MRCB-Quill REIT Unit (MQRE)      31.49
# 23   5121         Hektar Real Estate Investment Trust (HEKR)      31.31
# 24   7089                      Lii Hen Industries Bhd (LHEN)      30.33
# 25   7374                 Tien Wah Press Holdings Bhd (TWPH)      30.27
# 26   5070                                Protasco Bhd (PRTO)      29.67
# 27   5090             Media Chinese International Ltd (MDCH)      29.38
# 28   5212              Pavilion Real Estate Inv Trust (PREI)      29.23
# 29   2771                       Boustead Holdings Bhd (BOUS)      29.12
# ..    ...                                                ...        ...
# 78   5024                     Hup Seng Industries Bhd (HSIB)      11.54
# 79   5112                          TH Plantations Bhd (THPB)      11.40
# 80   7107               Oriental Food Industries Hold (OFIH)      11.27
# 81   9148          Advanced Packaging Tech (Malaysia) (APTB)      11.20
# 82   6963                             VS Industry Bhd (VSID)      11.09
# 83   5094                      CSC Steel Holdings Bhd (CSTH)      11.08
# 84   1724                   Paramount Corporation Bhd (PRMS)      10.76
# 85   5062                                Hua Yang Bhd (HUAY)      10.66
# 86   7133                 United U Li Corporation Bhd (UULI)      10.63
# 87   5147                        Samchem Holdings Bhd (SAHB)      10.56
# 88   5005                                Unisem M Bhd (UNSM)      10.55
# 89   5125                  Pantech Group Holdings Bhd (PNTE)      10.48
# 90   5202                   MSM Malaysia Holdings Bhd (MSMH)      10.48
# 91   5159                   Yoong Onn Corporation Bhd (YGON)      10.39
# 92   6173                          Bina Darulaman Bhd (BDBS)      10.23
# 93   5007                      Chin Well Holdings Bhd (CWHB)      10.22
# 94   2836              Carlsberg Brewery Malaysia Bhd (CBMS)      10.19
# 95   5015                 APM Automotive Holdings Bhd (APMA)       9.99
# 96   5138           Hap Seng Plantations Holdings Bhd (HAPP)       9.98
# 97   3662                     Malayan Flour Mills Bhd (MFMS)       9.84
# 98   5053                            OSK Holdings Bhd (OSKH)       9.79
# 99   6556                       Ann Joo Resources Bhd (ANNJ)       9.74
# 100  6645           Lingkaran Trans Kota Holdings Bhd (LTKH)       9.55
# 101  7033                Kumpulan H & L High-Tech Bhd (KHLH)       9.42
# 102  5681                       Petronas Dagangan Bhd (PETR)       9.41
# 103  5081               Esthetics International Group (ESTH)       9.24
# 104  5099                                 Airasia Bhd (AIRA)       9.13
# 105  5278                       Rhone Ma Holdings Bhd (RHON)       8.86
# 106  5162                                 ECS ICT Bhd (ECSI)       8.75
# 107  5143                     Luxchem Corporation Bhd (LCBH)       8.50
#
#      yield_mean                                                url
# 0      16.56330  https://www.investing.com/equities/tambun-inda...
# 1      24.05500  https://www.investing.com/equities/symphony-ho...
# 2      23.67000  https://www.investing.com/equities/jcy-interna...
# 3      23.64500  https://www.investing.com/equities/boustead-pl...
# 4      15.21670  https://www.investing.com/equities/star-media-...
# 5      45.45000  https://www.investing.com/equities/silk-holdin...
# 6      21.01500  https://www.investing.com/equities/taliworks-c...
# 7      20.51500  https://www.investing.com/equities/media-prima...
